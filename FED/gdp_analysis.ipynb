# %%
# Importing relevant modules

from load_data import load_data # to load data
from clean_data import clean_and_wrangle_gdp_data # to clean data
from plot_data import group_country_data, plot_country_gdp_data

# %%
# Insert the hard coded variables that will be used to obtain the relevent data

countries=["United Kingdom", "United States", "Brazil", "Japan", "China", "Germany", "Switzerland"]
indicator="NY.GDP.PCAP.PP.CD"
# Different indiciators can be found by searching the API as follows:
# print(wb.series.info(q="search term")
start_year=2000
end_year=2022

# %%
# Loading data using parameters and wbgapi

relevant_data = load_data(
    countries=countries,
    indicator=indicator,
    start_year=start_year,
    end_year=end_year,
    debug=True 
)
# Out:
# GBR
# Printing country code for 'United Kingdom' ...
# If you are thrown an error or you obtain an unexpected country code
# Please try a different query
#
# USA
# Printing country code for 'United States' ...
# If you are thrown an error or you obtain an unexpected country code
# Please try a different query
#
# BRA
# Printing country code for 'Brazil' ...
# If you are thrown an error or you obtain an unexpected country code
# Please try a different query
#
# JPN
# Printing country code for 'Japan' ...
# If you are thrown an error or you obtain an unexpected country code
# Please try a different query
#
# CHN
# Printing country code for 'China' ...
# If you are thrown an error or you obtain an unexpected country code
# Please try a different query
#
# DEU
# Printing country code for 'Germany' ...
# If you are thrown an error or you obtain an unexpected country code
# Please try a different query
#
# CHE
# Printing country code for 'Switzerland' ...
# ...

# %%
# Displaying raw data from API

display(relevant_data)
# Out:
#                YR2000        YR2001        YR2002        YR2003        YR2004  \
# economy
# BRA       8995.851894   9203.897339   9511.453991   9694.265706  10409.076253
# CHE      36695.207055  37822.927507  38704.958460  38737.307926  40176.570742
# CHN       2917.602155   3208.585838   3532.315658   3939.018856   4427.657138
# DEU      27202.476085  28376.904087  29178.637466  29909.808721  31334.731517
# GBR      26529.852173  27915.530440  29089.053677  30317.524314  32055.471764
# JPN      27287.270191  27942.346651  28623.588448  29392.248992  30830.658447
# USA      36329.970260  37133.620397  37997.742430  39490.302390  41724.641198
#
#                YR2005        YR2006        YR2007        YR2008        YR2009  \
# economy
# BRA      10956.122921  11615.640462  12524.568041  13284.394690  13222.877694
# CHE      41524.848873  46275.549484  50929.492704  53808.784113  52971.373276
# CHN       5056.987526   5843.353091   6820.040847   7583.348896   8305.841100
# ...

# %%
# Cleaning and wrangling data

clean_data = clean_and_wrangle_gdp_data(relevant_data)

# %%
# GDP data cleaned

display(clean_data)
# Out:
#     country  gdp_per_capita  year
# 0       BRA          8996.0  2000
# 1       CHE         36695.0  2000
# 2       CHN          2918.0  2000
# 3       DEU         27202.0  2000
# 4       GBR         26530.0  2000
# ..      ...             ...   ...
# 149     CHN         20407.0  2021
# 150     DEU         61940.0  2021
# 151     GBR         52842.0  2021
# 152     JPN         44549.0  2021
# 153     USA         71056.0  2021
#
# [154 rows x 3 columns]

# %%
# Returning a dicrtionary of GDP data grouped by country

grouped_country_data = group_country_data(clean_data)

# %%
# Displaying data

display(grouped_country_data)
# Out:
# {'BRA':     country  gdp_per_capita  year
#  0       BRA          8996.0  2000
#  7       BRA          9204.0  2001
#  14      BRA          9511.0  2002
#  21      BRA          9694.0  2003
#  28      BRA         10409.0  2004
#  35      BRA         10956.0  2005
#  42      BRA         11616.0  2006
#  49      BRA         12525.0  2007
#  56      BRA         13284.0  2008
#  63      BRA         13223.0  2009
#  70      BRA         14257.0  2010
#  77      BRA         14989.0  2011
#  84      BRA         14962.0  2012
#  91      BRA         15470.0  2013
#  98      BRA         15565.0  2014
#  105     BRA         14568.0  2015
#  112     BRA         14057.0  2016
#  119     BRA         14294.0  2017
#  126     BRA         15165.0  2018
#  133     BRA         15741.0  2019
#  140     BRA         15759.0  2020
#  147     BRA         17673.0  2021,
#  'CHE':     country  gdp_per_capita  year
#  1       CHE         36695.0  2000
#  8       CHE         37823.0  2001
# ...

# %%
GDP_plot = plot_country_gdp_data(grouped_country_data)

# %% [markdown]
# ### Analysis of the Data
#
# * We see an increase across all countries from 2000 until 2020
# * All countries experience a significant dip during the financial crash and the COVID-19 pandemic, Chine (CHN) and Brazil (BRA) are not affected as much.
# * Swizerland (CHE) has the highest GDP/ capita since 2006
